# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6
data = pd.read_csv("Electric_Production.csv",index_col=0)
data.head()
# Out:
#             IPG2211A2N
# DATE
# 1939-01-01      3.3842
# 1939-02-01      3.4100
# 1939-03-01      3.4875
# 1939-04-01      3.5133
# 1939-05-01      3.5133

# %%
# We now convert this data into a time series data. Currently the date values are stored as string type.

# %%
data.index
# Out:
# Index(['1939-01-01', '1939-02-01', '1939-03-01', '1939-04-01', '1939-05-01',
#        '1939-06-01', '1939-07-01', '1939-08-01', '1939-09-01', '1939-10-01',
#        ...
#        '2017-09-01', '2017-10-01', '2017-11-01', '2017-12-01', '2018-01-01',
#        '2018-02-01', '2018-03-01', '2018-04-01', '2018-05-01', '2018-06-01'],
#       dtype='object', name='DATE', length=954)

# %%
data.index = pd.to_datetime(data.index)

# %%
data.head()
# Out:
#             IPG2211A2N
# DATE
# 1939-01-01      3.3842
# 1939-02-01      3.4100
# 1939-03-01      3.4875
# 1939-04-01      3.5133
# 1939-05-01      3.5133

# %%
data.index
# Out:
# DatetimeIndex(['1939-01-01', '1939-02-01', '1939-03-01', '1939-04-01',
#                '1939-05-01', '1939-06-01', '1939-07-01', '1939-08-01',
#                '1939-09-01', '1939-10-01',
#                ...
#                '2017-09-01', '2017-10-01', '2017-11-01', '2017-12-01',
#                '2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01',
#                '2018-05-01', '2018-06-01'],
#               dtype='datetime64[ns]', name='DATE', length=954, freq=None)

# %%
# Check for missing data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 954 entries, 1939-01-01 to 2018-06-01
# Data columns (total 1 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   IPG2211A2N  954 non-null    float64
# dtypes: float64(1)
# memory usage: 14.9 KB

# %%
# Rename column for ease

# %%
data.columns = ['energy_prod']

# %%
data.head()
# Out:
#             energy_prod
# DATE
# 1939-01-01       3.3842
# 1939-02-01       3.4100
# 1939-03-01       3.4875
# 1939-04-01       3.5133
# 1939-05-01       3.5133

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(data)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# %%
plt.subplot(411)
plt.plot(data, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals')
plt.legend(loc='best')
plt.tight_layout()

# %%
from pmdarima.arima import auto_arima
stepwise_model = auto_arima(data, start_p=1, start_q=1,
                           max_p=3, max_q=3, m=12,
                           start_P=0, seasonal=True,
                           d=1, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=3729.023, Time=0.53 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=4226.662, Time=0.04 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=4048.141, Time=0.17 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=3850.307, Time=0.28 sec
#  ARIMA(1,1,1)(0,1,0)[12]             : AIC=inf, Time=0.27 sec
#  ARIMA(1,1,1)(1,1,1)[12]             : AIC=3728.477, Time=0.71 sec
#  ARIMA(1,1,1)(1,1,0)[12]             : AIC=3890.232, Time=0.46 sec
#  ARIMA(1,1,1)(2,1,1)[12]             : AIC=3705.062, Time=0.99 sec
#  ARIMA(1,1,1)(2,1,0)[12]             : AIC=3775.519, Time=0.74 sec
#  ARIMA(1,1,1)(2,1,2)[12]             : AIC=3690.617, Time=2.79 sec
#  ARIMA(1,1,1)(1,1,2)[12]             : AIC=3722.200, Time=1.84 sec
#  ARIMA(0,1,1)(2,1,2)[12]             : AIC=3789.730, Time=2.17 sec
#  ARIMA(1,1,0)(2,1,2)[12]             : AIC=3832.019, Time=2.41 sec
#  ARIMA(2,1,1)(2,1,2)[12]             : AIC=3690.547, Time=3.41 sec
#  ARIMA(2,1,1)(1,1,2)[12]             : AIC=3718.849, Time=2.62 sec
#  ARIMA(2,1,1)(2,1,1)[12]             : AIC=3701.513, Time=1.70 sec
#  ARIMA(2,1,1)(1,1,1)[12]             : AIC=3725.593, Time=1.18 sec
#  ARIMA(2,1,0)(2,1,2)[12]             : AIC=3769.261, Time=2.90 sec
#  ARIMA(3,1,1)(2,1,2)[12]             : AIC=3687.480, Time=3.26 sec
#  ARIMA(3,1,1)(1,1,2)[12]             : AIC=3715.432, Time=2.93 sec
#  ARIMA(3,1,1)(2,1,1)[12]             : AIC=3698.356, Time=1.96 sec
#  ARIMA(3,1,1)(1,1,1)[12]             : AIC=3722.031, Time=1.39 sec
#  ARIMA(3,1,0)(2,1,2)[12]             : AIC=3762.332, Time=3.00 sec
#  ARIMA(3,1,2)(2,1,2)[12]             : AIC=3688.154, Time=5.73 sec
#  ARIMA(2,1,2)(2,1,2)[12]             : AIC=3688.924, Time=4.22 sec
#  ARIMA(3,1,1)(2,1,2)[12] intercept   : AIC=3690.587, Time=9.85 sec
#
# Best model:  ARIMA(3,1,1)(2,1,2)[12]
# Total fit time: 57.559 seconds
# 3687.480348028913

# %%
stepwise_model.aic()
# Out:
# 3687.480348028913

# %%
# Convert data to stationary time series

data2 = np.log(data)

# %%
# Train Test Split Data

# %%
data2.head()
# Out:
#             energy_prod
# DATE
# 1939-01-01     1.219118
# 1939-02-01     1.226712
# 1939-03-01     1.249185
# 1939-04-01     1.256556
# 1939-05-01     1.256556

# %%
data2.tail()
# Out:
#             energy_prod
# DATE
# 2018-02-01     4.672881
# 2018-03-01     4.638972
# 2018-04-01     4.534820
# 2018-05-01     4.548848
# 2018-06-01     4.652571

# %%
train = data2.loc['1939-01-01':'2016-12-01']
test = data2.loc['2016-01-01':]

# %%
train.tail()
# Out:
#             energy_prod
# DATE
# 2016-08-01     4.749101
# 2016-09-01     4.626763
# 2016-10-01     4.507477
# 2016-11-01     4.524756
# 2016-12-01     4.729683

# %%
test.head()
# Out:
#             energy_prod
# DATE
# 2016-01-01     4.763991
# 2016-02-01     4.665832
# 2016-03-01     4.548298
# 2016-04-01     4.481619
# 2016-05-01     4.495620

# %%
test.tail()
# Out:
#             energy_prod
# DATE
# 2018-02-01     4.672881
# 2018-03-01     4.638972
# 2018-04-01     4.534820
# 2018-05-01     4.548848
# 2018-06-01     4.652571

# %%
len(test)
# Out:
# 30

# %%
stepwise_model.fit(train)
# Out:
# ARIMA(order=(3, 1, 1), scoring_args={}, seasonal_order=(2, 1, 2, 12),
#       suppress_warnings=True, with_intercept=False)

# %%
future_forecast = stepwise_model.predict(n_periods=30)

# %%
future_forecast
# Out:
# array([4.82728256, 4.72486119, 4.6214436 , 4.51704471, 4.53711823,
#        4.65965563, 4.74959821, 4.74958764, 4.64163887, 4.54347855,
#        4.58055854, 4.73804866, 4.82622002, 4.74653377, 4.65282934,
#        4.53369195, 4.55303173, 4.67117924, 4.75888426, 4.75375952,
#        4.65284803, 4.55667061, 4.59186145, 4.73128774, 4.82588593,
#        4.74431422, 4.64917956, 4.53909606, 4.55767096, 4.67907036])

# %%
future_forecast = pd.DataFrame(future_forecast,index = test.index,columns=['Prediction'])

future_forecast.head()
# Out:
#             Prediction
# DATE
# 2016-01-01    4.827283
# 2016-02-01    4.724861
# 2016-03-01    4.621444
# 2016-04-01    4.517045
# 2016-05-01    4.537118

# %%
test.head()
# Out:
#             energy_prod
# DATE
# 2016-01-01     4.763991
# 2016-02-01     4.665832
# 2016-03-01     4.548298
# 2016-04-01     4.481619
# 2016-05-01     4.495620

# %%
pd.concat([test,future_forecast],axis=1).plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
future_forecast2 = np.exp(future_forecast)

# %%
pd.concat([data,future_forecast2],axis=1).plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
#Check r2 score for accuracy of prediction

# %%
from sklearn.metrics import r2_score
r2_score(np.exp(test),future_forecast2)
# Out:
# 0.6957749392784391
